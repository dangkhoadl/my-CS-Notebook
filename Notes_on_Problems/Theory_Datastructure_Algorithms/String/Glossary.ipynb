# %% [markdown]
# ## Anagram
# - Words that have rearranged characters. Eg:
#     + "listen" = "silent"
#     + "funeral" = "real fun"
# - Solve
#     + Sort characters -> compare
#     + Count number of each char -> compare
