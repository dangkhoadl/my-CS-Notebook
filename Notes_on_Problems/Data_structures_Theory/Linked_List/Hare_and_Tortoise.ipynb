# %% [markdown]
# ## Hare and tortoise
# #### Detect if there is a cycle
# ```C++
# int tor = 0;
# int hare = 0;
#
# do {
#     tor = a[tor];
#     hare = a[a[hare]];
# } while(tor != hare);
# ```
#
#
# #### Find the entrance
#
# <img src="./img/2.jpg" alt="drawing" width="600"/>
#
#
# ```C++
# int p1 = 0;
# int p2 = tor;
# while (p1 != p2) {
#     p1 = a[p1];
#     p2 = a[p2];
# }
#
# return p1;
# ```
